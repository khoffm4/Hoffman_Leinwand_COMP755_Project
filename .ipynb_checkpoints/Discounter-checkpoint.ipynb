# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import os
from random import *
import pickle
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
os.chdir('C:\\Users\\Kepa\\Documents\\Github2\\Hoffman_Leinwand_COMP755_Project')

# %%
Demand_Matrix = pd.read_csv('Demand_Matrix.csv', header= None)
Demand_Matrix = Demand_Matrix.values
Time_Matrix = pd.read_csv('Time_Matrix.csv', header = None)
Time_Matrix = Time_Matrix.values
Time_Matrix[Time_Matrix == -0] = np.Inf
OTime_dataframe = pandas.read_csv('neighbors_2017_combined_train_and_test_with_predictions_fixed_with_zeros.csv')
ODemand_dataframe = pandas.read_csv('Demand_Data3_Total_CV_2017_with_zeros.csv')

PU_DO_list = Time_dataframe['PU_DO']
PU_DO_list = np.unique(PU_DO_list)
PU_DO_list = PU_DO_list.tolist()

PULoc_list = np.unique(Demand_dataframe['PULocationID'])
PULoc_list = PULoc_list.tolist() 

#Remember to change:
chosen_Time_list = 1262

dictionary = {'100': 0, '107': 1, '113': 2, '114': 3, '12': 4, '125': 5, '13': 6, '137': 7, '140': 8, '141': 9, '142': 10, '143': 11, '144': 12, '148': 13, '151': 14, '158': 15, '161': 16, '162': 17, '163': 18, '164': 19, '170': 20, '186': 21, '209': 22, '211': 23, '224': 24, '229': 25, '230': 26, '231': 27, '232': 28, '233': 29, '234': 30, '236': 31, '237': 32, '238': 33, '239': 34, '24': 35, '246': 36, '249': 37, '261': 38, '262': 39, '263': 40, '4': 41, '43': 42, '45': 43, '48': 44, '50': 45, '68': 46, '79': 47, '87': 48, '88': 49, '90': 50}

# %%
print(OTime_dataframe)
# Out:
#          Unnamed: 0  OLS_CV_Prediction  OLS_Prediction  OLS_fitted_value  \
# 0                 0         406.913122       -1.000000        407.939954
# 1                 1         296.322699       -1.000000        296.614283
# 2                 2         376.331127       -1.000000        376.436955
# 3                 3         387.360999       -1.000000        386.823059
# 4                 4         421.656756       -1.000000        423.522370
# 5                 5         261.749575       -1.000000        260.728148
# 6                 6         363.038591       -1.000000        362.397935
# 7                 7         257.651050       -1.000000        257.602779
# 8                 8         324.504269       -1.000000        324.761492
# 9                 9         295.462329       -1.000000        295.705884
# 10               10         246.562657       -1.000000        246.351286
# 11               11         320.373957       -1.000000        320.900264
# 12               12         291.899203       -1.000000        291.541252
# 13               13         337.843449       -1.000000        338.042386
# 14               14         249.979706       -1.000000        249.854418
# 15               15         297.763621       -1.000000        296.635051
# 16               16         337.186908       -1.000000        336.622542
# 17               17         263.657526       -1.000000        263.223444
# 18               18         314.393341       -1.000000        314.736123
# 19               19         357.800423       -1.000000        357.006544
# 20               20         238.900819       -1.000000        239.165033
# 21               21         249.522022       -1.000000        249.040188
# 22               22         198.815329       -1.000000        196.707410
# 23               23         302.324900       -1.000000        302.471090
# 24               24         217.378254       -1.000000        217.296167
# 25               25          59.917538       -1.000000         60.105056
# 26               26          39.198928       -1.000000         39.493705
# 27               27           7.032770       -1.000000          6.443621
# 28               28         257.395428       -1.000000        256.957558
# 1997250            6    23     10  2017/12/31 23   787.080000
# 1997251            6    23     10  2017/12/31 23   199.000000
# 1997252            6    23     10  2017/12/31 23   376.000000
# 1997253            6    23     10  2017/12/31 23   351.500000
# 1997254            6    23     10  2017/12/31 23   233.666667
# 1997255            6    23     10  2017/12/31 23   321.000000
# 1997256            6    23     10  2017/12/31 23   444.321429
# 1997257            6    23     10  2017/12/31 23   767.000000
# 1997258            6    23     10  2017/12/31 23   445.000000
# 1997259            6    23     10  2017/12/31 23   450.750000
# 1997260            6    23     10  2017/12/31 23   266.900000
# 1997261            6    23     10  2017/12/31 23   409.769231
# 1997262            6    23     10  2017/12/31 23   581.764706
# 1997263            6    23     10  2017/12/31 23   220.750000
# 1997264            6    23     10  2017/12/31 23   306.300000
# 1997265            6    23     10  2017/12/31 23   324.888889
# 1997266            6    23     10  2017/12/31 23   343.166667
# 1997267            6    23     10  2017/12/31 23   371.764706
# 1997268            6    23     10  2017/12/31 23   222.833333
# 1997269            6    23     10  2017/12/31 23   283.647059
# 1997270            6    23     10  2017/12/31 23   224.750000
# 1997271            6    23     10  2017/12/31 23   383.000000
# 1997272            6    23     10  2017/12/31 23   149.500000
# 1997273            6    23     10  2017/12/31 23     0.000000
# 1997274            6    23     10  2017/12/31 23     0.000000
# 1997275            6    23     10  2017/12/31 23   145.000000
# 1997276            6    23     10  2017/12/31 23   356.500000
# 1997277            6    23     10  2017/12/31 23   279.100000
# 1997278            6    23     10  2017/12/31 23   245.428571
# 1997279            6    23     10  2017/12/31 23   324.000000
#
# [1997280 rows x 14 columns]

# %%
print(Time_Matrix)
# Out:
# [[373.3523865         inf         inf ...         inf         inf
#           inf]
#  [        inf         inf         inf ...         inf         inf
#           inf]
#  [        inf         inf         inf ...         inf         inf
#           inf]
#  ...
#  [        inf         inf         inf ...         inf 157.7098694
#           inf]
#  [        inf         inf         inf ... 229.2384033         inf
#           inf]
#  [        inf         inf         inf ...         inf         inf
#           inf]]

# %%
correct_demand_decision = 0
correct_time_decision = 0
correct_discount_decision = 0
for i in range(len(Demand_Matrix)):
    current_loc = str(PULoc_list[i])
    #print('current_loc', current_loc)
    neighbors = []
    for j in range(len(PU_DO_list)):
        #For each location, get its neighbors
        current_PU_DO = PU_DO_list[j]
        [current_loc_candidate,destination]  = current_PU_DO.split('_')
        if current_loc_candidate != current_loc:
            pass
        else:
            neighbors.append(destination)
    #print(neighbors)
    
    #Find the estiamted and true demand/time for each neighbor
    Estimated_Demand = []
    True_Demand = []
    Estimated_Time = []
    True_Time = []
    for j in range(len(neighbors)):
        current_neighbor = neighbors[j]
        #print('current neighbor', current_neighbor)
        
        #True Demand
        dataframe = ODemand_dataframe
        dataframe = dataframe[dataframe['PULocationID'] == int(current_neighbor)]
        dataframe = dataframe[dataframe['Month'] > 10]
        dataframe = dataframe['passenger_count']
        dataset = dataframe.values
        dataset = dataset.astype('float32')
        dataset = np.reshape(dataset, (len(dataset),1))

        #print('This is the True deamnd:', test2Actual)
        True_Demand.append(dataset[chosen_Time_list])
        
        #Estimated Demand
        #print('Estimated Demand', Demand_Matrix[int(dictionary[current_neighbor])])
        Estimated_Demand.append( PULoc_list.index(int(current_neighbor)))
        
        
        #True Time
        dataframe = OTime_dataframe
        PULoc = str(current_loc) + '_' + str(current_neighbor)
        dataframe = dataframe[dataframe['PU_DO'] == PULoc]
        dataframe = dataframe[dataframe['True_Month'] > 10]
        dataframe = dataframe['time_delta']
        dataset = dataframe.values
        dataset = dataset.astype('float32')
        dataset = np.reshape(dataset, (len(dataset),1))
        #print('True Time', dataset[chosen_Time_list] )
        tru_tim = dataset[chosen_Time_list]
        
        #If true time = 0, set to minimum:
        if  dataset[chosen_Time_list]==0:
            tru_tim = min( dataset[dataset > 0] )
            
        True_Time.append(tru_tim)
        
        #Estimated Time
        row = dictionary[current_loc]
        col = dictionary[current_neighbor]
        #print('Estimated Time:',Time_Matrix[row, col])
        Estimated_Time.append(Time_Matrix[row, col])
    
    #Add the current location
    #True Demand
    dataframe = ODemand_dataframe
    dataframe = dataframe[dataframe['PULocationID'] == int(current_loc)]
    dataframe = dataframe[dataframe['Month'] > 10]
    dataframe = dataframe['passenger_count']
    dataset = dataframe.values
    dataset = dataset.astype('float32')
    dataset = np.reshape(dataset, (len(dataset),1))
    True_Demand.append(dataset[chosen_Time_list])
    True_Demand = np.asarray(True_Demand)
    True_Demand = np.reshape(True_Demand, (len(True_Demand),))

    #Estimated Demand
    Estimated_Demand.append( PULoc_list.index(int(current_loc)))
    Estimated_Demand = np.asarray(Estimated_Demand)

        
    #True Time
    True_Time.append(0)
    True_Time = np.asarray(True_Time)
    
    #Estimated Time
    Estimated_Time.append(0)
    Estimated_Time = np.asarray(Estimated_Time)
    
        
        
    #Percentage correct guess which neighbor has the best demand
    actual_choice = np.argmax(True_Demand)
    estimated_choice = np.argmax(Estimated_Demand)
    if actual_choice == estimated_choice:
        correct_demand_decision = correct_demand_decision+1
        
        
    
    #Percentage correct guess which neighbor has the best time (infront cuz 0)
    actual_choice = np.argmin(True_Time)
    estimated_choice = np.argmin(Estimated_Time)       
    if actual_choice == estimated_choice:
        correct_time_decision = correct_time_decision+1

        
    #DIscounting FUnction
    Estimated_Discount =  Estimated_Demand - Estimated_Time/60 * Estimated_Demand
    print('Estimated Discount', Estimated_Discount)
    print('True demand shape:', True_Demand.shape)
    print('True Time shape:', True_Time.shape)
    True_Discount = True_Demand - True_Time/60 * True_Demand
    print('True Discount', True_Discount)
    
    #Percentage correct guess which neighbor has the best time (infront cuz 0)
    actual_choice = np.argmax(True_Discount)
    estimated_choice = np.argmax(Estimated_Discount)       
    if actual_choice == estimated_choice:
        correct_discount_decision = correct_discount_decision+1
        
    

        
        
        
correct_demand_decision = correct_demand_decision/  len(Demand_Matrix)  
correct_time_decision = correct_time_decision/  len(Demand_Matrix)  
correct_discount_decision = correct_discount_decision/len(Demand_Matrix)
# Out:
# Estimated Discount [ -3302.40402205 -10001.5754709   -2402.8110351       0.        ]
# True demand shape: (4,)
# True Time shape: (4,)
# True Discount [-3.5100e+02 -3.9000e+03 -6.2409e+04  2.9000e+01]
# Estimated Discount [-1.40380386e+02 -2.78669330e+03 -2.92802427e+02  1.00000000e+00]
# True demand shape: (4,)
# True Time shape: (4,)
# True Discount [-5977. -1892.   -74.    10.]
# Estimated Discount [-8.72034454e+01 -1.39473788e+04 -1.29434883e+04  2.00000000e+00]
# True demand shape: (4,)
# True Time shape: (4,)
# True Discount [array([-3060.], dtype=float32) array([-59141.668], dtype=float32)
#  array([-56416.], dtype=float32) 139.0]
# Estimated Discount [-3.97649917e+03 -8.49356750e+02  3.00000000e+00]
# True demand shape: (3,)
# True Time shape: (3,)
# True Discount [array([-87042.], dtype=float32) array([-234214.], dtype=float32) 42.0]
# Estimated Discount [-7.39860608e+03 -7.90994339e+03 -1.21757413e+04 -1.58235590e+04
#  -1.35096491e+04 -2.18113282e+04 -1.67751466e+04 -5.67434784e+02
#   4.00000000e+00]
# True demand shape: (9,)
# True Time shape: (9,)
# True Discount [array([-252825.44], dtype=float32) array([-91242.8], dtype=float32)
#  array([-269874.8], dtype=float32) array([-256635.72], dtype=float32)
#  array([-343295.88], dtype=float32) array([-156058.], dtype=float32)
#  array([-258610.95], dtype=float32) array([-26908.], dtype=float32) 362.0]
# Estimated Discount [-5.10505875e+03 -1.30014595e+04 -4.78698345e+03 -7.68687131e+03
#  -1.30980050e+04  5.00000000e+00]
# True demand shape: (6,)
# True Time shape: (6,)
# True Discount [ -6216.  -1260.  -5798. -10152.  -2904.     32.]
# Estimated Discount [-5.27893826e+03 -6.66796976e+03 -9.17740701e+03 -1.10832795e+04
#  -1.60313102e+04 -2.06092044e+03 -3.23473657e+03  6.00000000e+00]
# True demand shape: (8,)
# True Time shape: (8,)
# True Discount [array([-181131.42], dtype=float32) array([-164358.36], dtype=float32)
#  array([-188129.55], dtype=float32) array([-183703.88], dtype=float32)
#  array([-52903.5], dtype=float32) array([-42906.938], dtype=float32)
#  array([-176531.48], dtype=float32) 375.0]
# Estimated Discount [-5.56968994e+03 -1.28745097e+04 -1.51488336e+03  7.00000000e+00]
# True demand shape: (4,)
# True Time shape: (4,)
# True Discount [array([-50700.], dtype=float32) array([-36649.598], dtype=float32)
#  array([-158156.25], dtype=float32) 119.0]
# Estimated Discount [-6.30064075e+03 -1.03373312e+04 -1.16550293e+04 -1.30695521e+04
#  -2.13938268e+04 -2.76768951e+03 -4.31895520e+03  8.00000000e+00]
# True demand shape: (8,)
# True Time shape: (8,)
# True Discount [array([-194027.8], dtype=float32) array([-28379.998], dtype=float32)
#  array([-202504.4], dtype=float32) array([-34174.402], dtype=float32)
#  array([-73390.53], dtype=float32) array([-199777.17], dtype=float32)
#  array([-69076.555], dtype=float32) 318.0]
# Estimated Discount [-4.71678534e+03 -5.45952026e+03 -6.78543848e+03 -1.49324751e+04
#  -1.09877185e+04  0.00000000e+00  9.00000000e+00]
# True demand shape: (7,)
# True Time shape: (7,)
# True Discount [array([-87850.48], dtype=float32) array([-97343.555], dtype=float32)
#  array([-65873.5], dtype=float32) array([-34392.27], dtype=float32)
#  array([-10032.75], dtype=float32) array([-8559.143], dtype=float32) 293.0]
# Estimated Discount [-4.47641052e+03 -1.41059854e+04 -1.72380856e+03  1.00000000e+01]
# True demand shape: (4,)
# True Time shape: (4,)
# True Discount [ -169.  -3784.  -4310.5    79. ]
# Estimated Discount [-1.39671669e+01 -1.55567388e+04 -2.28238403e+03  1.10000000e+01]
# True demand shape: (4,)
# True Time shape: (4,)
# True Discount [-2.50000000e+02 -5.57853351e+04 -1.66690000e+04  3.70000000e+01]
# Estimated Discount [-8.94634668e+03 -9.90933077e+03 -1.43563786e+04 -2.63890772e+03
#   1.20000000e+01]
# True demand shape: (5,)
# True Time shape: (5,)
# True Discount [array([-164675.88], dtype=float32) array([-139597.72], dtype=float32)
#  array([-58062.715], dtype=float32) array([-108859.13], dtype=float32)
#  311.0]
# Estimated Discount [-1.28161945e+04 -8.17796777e+03 -1.32759439e+04 -2.22149670e+03
#  -3.21550757e+03  1.30000000e+01]
# True demand shape: (6,)
# True Time shape: (6,)
# True Discount [array([-129363.], dtype=float32) array([-177940.], dtype=float32)
#  array([-190674.53], dtype=float32) array([-172903.84], dtype=float32)
#  array([-193980.], dtype=float32) 298.0]
# Estimated Discount [-4.82131659e+03 -1.09358271e+04 -1.02037785e+04 -1.56220047e+04
#  -3.76028751e+03  1.40000000e+01]
# True demand shape: (6,)
# True Time shape: (6,)
# True Discount [array([-40537.715], dtype=float32) array([-129248.], dtype=float32)
#  array([-15139.801], dtype=float32) array([-166228.], dtype=float32)
#  array([-100279.25], dtype=float32) 307.0]
# Estimated Discount [-4.85406543e+03 -1.38871184e+04 -1.51244990e+04 -3.46542050e+03
#   1.50000000e+01]
# True demand shape: (5,)
# True Time shape: (5,)
# True Discount [array([-43142.], dtype=float32) array([-146746.11], dtype=float32)
#  array([-73680.94], dtype=float32) array([-106548.586], dtype=float32)
#  268.0]
# Estimated Discount [-4.27413757e+03 -6.74200711e+03 -1.10529880e+04 -1.07268246e+04
#  -1.81975586e+04 -4.10292142e+03  1.60000000e+01]
# True demand shape: (7,)
# True Time shape: (7,)
# True Discount [array([-68799.43], dtype=float32) array([-22301.25], dtype=float32)
#  array([-133812.], dtype=float32) array([-94043.75], dtype=float32)
#  array([-78999.56], dtype=float32) array([-104852.14], dtype=float32)
#  154.0]
# Estimated Discount [ -3947.5205072  -9869.8984982  -4663.0401294 -11656.4965192
#  -12274.7984327     17.       ]
# True demand shape: (6,)
# True Time shape: (6,)
# True Discount [array([-49395.5], dtype=float32) array([-37768.5], dtype=float32) -5330.0
#  array([-62416.], dtype=float32) array([-74294.], dtype=float32) 57.0]
# Estimated Discount [ -3807.9337772  -6614.5895236 -11726.3201895 -11230.544432
#      18.       ]
# True demand shape: (5,)
# True Time shape: (5,)
# True Discount [array([-99590.8], dtype=float32) array([-101925.], dtype=float32)
#  array([-11083.801], dtype=float32) array([-25900.], dtype=float32) 136.0]
# Estimated Discount [ -5978.580932  -10603.4809572 -11702.8719633     19.       ]
# True demand shape: (4,)
# True Time shape: (4,)
# True Discount [array([-99106.1], dtype=float32) array([-74635.], dtype=float32)
#  array([-37503.], dtype=float32) 173.0]
# Estimated Discount [ -4839.3147269 -12059.1035172 -12146.2479852 -10813.026992
#  -12873.721315      20.       ]
# True demand shape: (6,)
# True Time shape: (6,)
# True Discount [array([-47103.184], dtype=float32) array([-85826.32], dtype=float32)
#  array([-172791.84], dtype=float32) array([-221378.78], dtype=float32)
#  array([-71540.], dtype=float32) 373.0]
# Estimated Discount [ -7520.4980466  -8177.750426  -14335.3839105  -1408.8651124
#   -2006.3410032     21.       ]
# True demand shape: (6,)
# True Time shape: (6,)
# True Discount [array([-66220.], dtype=float32) array([-185372.53], dtype=float32)
#  array([-231873.94], dtype=float32) array([-179113.78], dtype=float32)
#  array([-141945.64], dtype=float32) 518.0]
# Estimated Discount [-6615.8908074 -8427.974166  -1112.8807984    22.       ]
# True demand shape: (4,)
# True Time shape: (4,)
# True Discount [array([-130806.266], dtype=float32) array([-152457.92], dtype=float32)
#  array([-35615.], dtype=float32) 200.0]
# Estimated Discount [ -5225.6147456 -13368.6840816  -9466.5388182 -15223.6723014
#   -1794.313965      23.       ]
# True demand shape: (6,)
# True Time shape: (6,)
# True Discount [array([-69146.], dtype=float32) array([-46398.332], dtype=float32)
#  array([-177256.67], dtype=float32) array([-95165.6], dtype=float32)
#  -1760.0 168.0]
# Estimated Discount [ -8386.8466794 -12518.0133351  -1630.337372   -3375.0230715
#      24.       ]
# True demand shape: (5,)
# True Time shape: (5,)
# True Discount [array([-48840.], dtype=float32) array([-3700.], dtype=float32)
#  array([-7712.], dtype=float32) array([-78997.305], dtype=float32) 105.0]
# Estimated Discount [-9660.598266   -973.7508546  -710.1742552    25.       ]
# True demand shape: (4,)
# True Time shape: (4,)
# True Discount [array([-65367.336], dtype=float32) array([-12874.908], dtype=float32)
#  array([-163624.], dtype=float32) 178.0]
# Estimated Discount [ -6969.6202387 -21822.8292858 -14022.5047926  -3235.5749512
#      26.       ]
# True demand shape: (5,)
# True Time shape: (5,)
# True Discount [array([-14022.], dtype=float32) array([-52208.], dtype=float32)
#  array([-67356.67], dtype=float32) array([-142543.5], dtype=float32) 99.0]
# Estimated Discount [-10530.9471428  -9830.9876112 -11004.441834  -12134.1027235
#  -11940.0980536     27.       ]
# True demand shape: (6,)
# True Time shape: (6,)
# True Discount [array([-192403.34], dtype=float32) array([-193142.9], dtype=float32)
#  array([-131587.25], dtype=float32) array([-176933.08], dtype=float32)
#  array([-188283.75], dtype=float32) 562.0]
# Estimated Discount [ -5193.6063084 -14447.435731  -11100.8296211 -13060.7589096
#  -11383.292236  -17913.1520072     28.       ]
# True demand shape: (7,)
# True Time shape: (7,)
# True Discount [array([-227984.66], dtype=float32) array([-212104.06], dtype=float32)
#  array([-138276.], dtype=float32) array([-70589.09], dtype=float32)
#  array([-37466.152], dtype=float32) array([-363568.06], dtype=float32)
#  394.0]
# Estimated Discount [ -7432.4003901  -9989.1999198 -12889.624146  -15953.1143499
#  -14245.5832233  -1604.496704   -2543.7218628     29.       ]
# True demand shape: (8,)
# True Time shape: (8,)
# True Discount [array([-220890.], dtype=float32) array([-277237.03], dtype=float32)
#  array([-199023.72], dtype=float32) array([-228315.25], dtype=float32)
#  array([-315878.], dtype=float32) array([-196480.83], dtype=float32)
#  array([-253909.08], dtype=float32) 417.0]
# Estimated Discount [ -5417.4139708 -11881.6990344  -9377.3382265  -8762.6084
#  -11284.005035      30.       ]
# True demand shape: (6,)
# True Time shape: (6,)
# True Discount [array([-171409.61], dtype=float32) array([-284505.8], dtype=float32)
#  array([-117117.], dtype=float32) array([-255073.64], dtype=float32)
#  array([-133307.19], dtype=float32) 248.0]
# Estimated Discount [ -4778.9752808  -6659.8247682 -10255.4747325 -12200.759032
#   -8614.078674  -10652.645264      31.       ]
# True demand shape: (7,)
# True Time shape: (7,)
# True Discount [array([-91086.91], dtype=float32) array([-21964.], dtype=float32)
#  array([-256031.16], dtype=float32) array([-141708.66], dtype=float32)
#  array([-105476.305], dtype=float32) array([-49381.816], dtype=float32)
#  378.0]
# Estimated Discount [ -3493.9138494  -9222.294618  -14027.3176877  -2595.3210448
#   -3422.0064696     32.       ]
# True demand shape: (6,)
# True Time shape: (6,)
# True Discount [array([-155026.22], dtype=float32) array([-114877.15], dtype=float32)
#  array([-200602.67], dtype=float32) array([-103741.38], dtype=float32)
#  array([-92500.28], dtype=float32) 434.0]
# Estimated Discount [-8566.5942694 -7254.5200176  -868.1793975 -1066.539841     33.       ]
# True demand shape: (5,)
# True Time shape: (5,)
# True Discount [array([-113740.], dtype=float32) array([-39216.], dtype=float32) -1952.0
#  -790.0 13.0]
# Estimated Discount [ -4498.5390624  -4008.878647   -9432.733918  -13235.184996
#      34.       ]
# True demand shape: (5,)
# True Time shape: (5,)
# True Discount [array([-40810.], dtype=float32) array([-27379.], dtype=float32)
#  array([-96012.], dtype=float32) array([-74037.82], dtype=float32) 205.0]
# Estimated Discount [-3519.7832026 -6008.6013786     0.        -3016.4043276    35.       ]
# True demand shape: (5,)
# True Time shape: (5,)
# True Discount [array([-50962.], dtype=float32) -1360.0 -1885.0
#  array([-73030.25], dtype=float32) 39.0]
# Estimated Discount [ -8244.6576842  -7307.140502   -8455.147218  -10866.691896
#      36.       ]
# True demand shape: (5,)
# True Time shape: (5,)
# True Discount [array([-50170.], dtype=float32) array([-110781.], dtype=float32)
#  array([-121352.], dtype=float32) array([-33943.637], dtype=float32) 230.0]
# Estimated Discount [-4430.1090392 -8298.7097157 -9621.9881289 -1932.6736452    37.       ]
# True demand shape: (5,)
# True Time shape: (5,)
# True Discount [array([-188307.62], dtype=float32) array([-263844.22], dtype=float32)
#  array([-158486.06], dtype=float32) array([-157519.73], dtype=float32)
#  354.0]
# Estimated Discount [ -4511.9316718   -633.7092286 -10758.5230399  -6583.7346498
#  -11458.470033  -21705.6079104  -2040.754242      38.       ]
# True demand shape: (8,)
# True Time shape: (8,)
# True Discount [array([-23541.], dtype=float32) array([-40213.766], dtype=float32)
#  array([-131348.], dtype=float32) array([-5986.5], dtype=float32)
#  array([-100581.78], dtype=float32) array([-53588.75], dtype=float32)
#  array([-14120.], dtype=float32) 188.0]
# Estimated Discount [-5143.3417968     0.         -599.266815     39.       ]
# True demand shape: (4,)
# True Time shape: (4,)
# True Discount [array([-20265.], dtype=float32) -2407.0 -2080.0 12.0]
# Estimated Discount [ -4907.3708502  -8779.2731936 -10186.2870488 -11452.2308352
#      40.       ]
# True demand shape: (5,)
# True Time shape: (5,)
# True Discount [array([-29308.], dtype=float32) array([-115392.75], dtype=float32)
#  array([-116046.], dtype=float32) array([-41952.], dtype=float32) 140.0]
# Estimated Discount [ -4730.432007   -4593.876801  -10574.649354  -12340.7099616
#   -3811.8112788     41.       ]
# True demand shape: (6,)
# True Time shape: (6,)
# True Discount [array([-129128.92], dtype=float32) array([-79713.25], dtype=float32)
#  array([-109897.06], dtype=float32) array([-250678.39], dtype=float32)
#  array([-79495.055], dtype=float32) 464.0]
# Estimated Discount [ -6751.16333   -10531.7219853 -14283.662415   -1100.3421632
#      42.       ]
# True demand shape: (5,)
# True Time shape: (5,)
# True Discount [array([-155303.64], dtype=float32) array([-280186.78], dtype=float32)
#  array([-72327.516], dtype=float32) array([-145066.73], dtype=float32)
#  610.0]
# Estimated Discount [-4991.91681   -8585.1718764 -9791.9011531 -9656.8616634 -1422.274536
#     43.       ]
# True demand shape: (6,)
# True Time shape: (6,)
# True Discount [array([-101362.75], dtype=float32) array([-145246.2], dtype=float32)
#  array([-169085.78], dtype=float32) array([-193510.77], dtype=float32)
#  array([-187432.45], dtype=float32) 731.0]
# Estimated Discount [ -5621.49086  -10725.643845   -932.44635      44.      ]
# True demand shape: (4,)
# True Time shape: (4,)
# True Discount [array([-33480.953], dtype=float32) array([-180572.72], dtype=float32)
#  array([-163696.4], dtype=float32) 284.0]
# Estimated Discount [-5581.3658754 -6969.492981  -8902.5006092 -1653.0616456    45.       ]
# True demand shape: (5,)
# True Time shape: (5,)
# True Discount [array([-174307.], dtype=float32) array([-57669.23], dtype=float32)
#  array([-84042.49], dtype=float32) array([-161391.67], dtype=float32)
#  610.0]
# Estimated Discount [-12378.9889522  -2084.2963254  -2252.4922483  -2921.9667968
#      46.       ]
# True demand shape: (5,)
# True Time shape: (5,)
# True Discount [array([-32843.25], dtype=float32) array([-168093.75], dtype=float32)
#  array([-39686.5], dtype=float32) array([-88086.], dtype=float32) 104.0]
# Estimated Discount [-5233.0545045 -6789.443848  -5477.689697  -7823.2062376 -3226.8117672
#  -3780.135498     47.       ]
# True demand shape: (7,)
# True Time shape: (7,)
# True Discount [array([-75844.], dtype=float32) array([-69402.664], dtype=float32)
#  array([-15988.5], dtype=float32) array([-26730.], dtype=float32)
#  array([-136907.36], dtype=float32) array([-75503.89], dtype=float32)
#  242.0]
# Estimated Discount [  -79.83443451  -316.05307    -6419.8248147  -9886.5405258
#  -1732.107544   -2251.3243258     48.        ]
# True demand shape: (7,)
# True Time shape: (7,)
# True Discount [array([-3760.], dtype=float32) array([-70681.5], dtype=float32) -39.0
#  array([-66708.67], dtype=float32) array([-25477.5], dtype=float32)
#  array([-13270.666], dtype=float32) 172.0]
# Estimated Discount [-4285.6738732 -8542.497255     49.       ]
# True demand shape: (3,)
# True Time shape: (3,)
# True Discount [array([-56282.668], dtype=float32) array([-67160.], dtype=float32) 162.0]
# Estimated Discount [-5072.423706  -9442.615266  -9905.3422237    50.       ]
# True demand shape: (4,)
# True Time shape: (4,)
# True Discount [array([-97321.914], dtype=float32) array([-149263.61], dtype=float32)
#  array([-37767.13], dtype=float32) 292.0]

# %%
#Percent of the Time we correctly guessed which area would be the Hottest accofdint to LSTM
print('Demand correct', correct_demand_decision)
print('Time correct', correct_time_decision)
print('Discount correct', correct_discount_decision)
# Out:
# Demand correct 0.29411764705882354
# Time correct 1.0
# Discount correct 1.0

# %%
print(np.asarray(Estimated_Time)/ 3600)
# Out:
# [0.07072811 0.06272894 0.05643051 0.05643051]

# %%
print(Time_Matrix)
# Out:
# [[373.3523865         inf         inf ...         inf         inf
#           inf]
#  [        inf         inf         inf ...         inf         inf
#           inf]
#  [        inf         inf         inf ...         inf         inf
#           inf]
#  ...
#  [        inf         inf         inf ...         inf 157.7098694
#           inf]
#  [        inf         inf         inf ... 229.2384033         inf
#           inf]
#  [        inf         inf         inf ...         inf         inf
#           inf]]
